# %% [markdown]
# ## Python Programming

# %% [markdown]
# If you're diving into data science for the first time, learning Python programming goes hand-in-hand with learning data science fundamentals. There's no limit to what you can do by learning Python programming, and expanding your skill set means expanding your career opportunities — and your earning potential. As artificial intelligence (AI) and machine learning become increasingly prevalent in the world of data science, having a strong foundation in Python will be essential.

# %% [markdown]
# There's a lot of discussion about and enthusiasm for data science, especially with the recent popularity of artificial intelligence (AI) in software like ChatGPT. It is a field that uses algorithms, scientific methods, and systems to extract knowledge and insights from structured and unstructured data. It's behind many of the technologies we see and use today!

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
print(1 + 2)
# Out:
# 3
